# %% [markdown]
# # Gradient Descent Algorithm

# %%
# Input parameters
start_x=16
learning_rate=0.1
n_iterations=100
# ----------------

# Store the minimum gradient results
minimum = []

# Set x to the starting point x (satrt_x)
x = start_x

for i in range(n_iterations):
    # Calculate gradient (derivative of x²)
    gradient = 2 * x

    # Update x by moving opposite to the gradient
    x = x - learning_rate * gradient

    print(f"Iteration {i}: x = {x:.4f}, f(x) = {x*x:.4f}")
    minimum.append(x)
# Out:
# Iteration 0: x = 12.8000, f(x) = 163.8400
# Iteration 1: x = 10.2400, f(x) = 104.8576
# Iteration 2: x = 8.1920, f(x) = 67.1089
# Iteration 3: x = 6.5536, f(x) = 42.9497
# Iteration 4: x = 5.2429, f(x) = 27.4878
# Iteration 5: x = 4.1943, f(x) = 17.5922
# Iteration 6: x = 3.3554, f(x) = 11.2590
# Iteration 7: x = 2.6844, f(x) = 7.2058
# Iteration 8: x = 2.1475, f(x) = 4.6117
# Iteration 9: x = 1.7180, f(x) = 2.9515
# Iteration 10: x = 1.3744, f(x) = 1.8889
# Iteration 11: x = 1.0995, f(x) = 1.2089
# Iteration 12: x = 0.8796, f(x) = 0.7737
# Iteration 13: x = 0.7037, f(x) = 0.4952
# Iteration 14: x = 0.5629, f(x) = 0.3169
# Iteration 15: x = 0.4504, f(x) = 0.2028
# Iteration 16: x = 0.3603, f(x) = 0.1298
# Iteration 17: x = 0.2882, f(x) = 0.0831
# Iteration 18: x = 0.2306, f(x) = 0.0532
# Iteration 19: x = 0.1845, f(x) = 0.0340
# Iteration 20: x = 0.1476, f(x) = 0.0218
# Iteration 21: x = 0.1181, f(x) = 0.0139
# Iteration 22: x = 0.0944, f(x) = 0.0089
# ...

# %%
import matplotlib.pyplot as plt

# Plots the training and validation loss curves
plt.title('Gradient Desccent Line Plot')
plt.xlabel('Iteration')
plt.ylabel('Gradient')
plt.plot(minimum, label='Minimum')
plt.show()

# %%
# %whos
# Out:
# Variable        Type      Data/Info
# -----------------------------------
# gradient        float     8.148143905337951e-09
# i               int       99
# learning_rate   float     0.1
# minimum         list      n=100
# n_iterations    int       100
# plt             module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# start_x         int       16
# x               float     3.2592575621351803e-09
